# %%
import glob
import pandas as pd

frames = []
for file in glob.glob('..\..\data\data_raw\*.csv'):
    frames.append(pd.read_csv(file, dtype=object))
    
frames[0] # print Destiny2 data for example
# Out:
#       Unnamed: 0 recommendationid language  \
# 0              0         77150559  english
# 1              1         77149337  english
# 2              2         77148928  english
# 3              3         77148628  english
# 4              4         77147835  english
# ...          ...              ...      ...
# 43047         48         55384560  english
# 43048         49         55384469  english
# 43049         50         55384249  english
# 43050         51         55384009  english
# 43051         52         55384007  english
#
#                                                   review timestamp_created  \
# 0      always a good game but i think that they could...        1602026144
# 1                                                its fun        1602023991
# 2                                             rip cade-6        1602023202
# 3      I got the free version of Destiny 2 just to tr...        1602022671
# ...
