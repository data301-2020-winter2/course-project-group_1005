# %% [markdown]
# # Milestone 01 - Load your dataset from a file or URL
# ***

# %%
import pandas as pd
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #### Action Games Datasets

# %%
# Destiny 2
action1 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Action)%201085660_Destiny2.csv", low_memory=False)
action1.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77150559  english
# 1           1          77149337  english
# 2           2          77148928  english
# 3           3          77148628  english
# 4           4          77147835  english
#
# ...

# %%
# Red Dead Redemption 2
action2 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Action)%201174180_RedDeadRedemption2.csv", low_memory=False)
action2.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77060058  english
# 1           1          77059990  english
# 2           2          77059784  english
# 3           3          77059467  english
# 4           4          77059201  english
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              review  \
# ...

# %%
# Tom Clancy's Rainbow Six Seige
action3 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Action)%20359550_TomClancysRainbowSixSiege.csv", low_memory=False)
action3.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77154614  english
# 1           1          77154456  english
# 2           2          77154449  english
# 3           3          77154432  english
# 4           4          77154274  english
#
#                                            review  timestamp_created  \
# 0  never touch this game if you wish a happy life         1602034161
# 1                                  good cant wait         1602033846
# 2         Good shit, good and bad but mostly good         1602033837
# 3                                       it cool\n         1602033802
# 4                               is good sometimes         1602033515
#
#    timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0         1602034161      True         0            0                  0.0
# 1         1602033846      True         0            0                  0.0
# ...

# %% [markdown]
# #### Adventure Games Datasets

# %%
# Sea of Thieves
adventure1 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Adventure)%201172620_SeaofThieves.csv", low_memory=False)
adventure1.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77059980  english
# 1           1          77055763  english
# 2           2          77054506  english
# 3           3          76791627  english
# 4           4          77052629  english
#
#                                                                                                                                                                                                                                                                                                                                                                                                                 review  \
# ...

# %%
# Rust
adventure2 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Adventure)%20252490_Rust.csv", low_memory=False)
adventure2.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77152725  english
# 1           1          77152675  english
# 2           2          77152616  english
# 3           3          77152335  english
# 4           4          77152090  english
#
#                                                           review  \
# 0                                                   is good game
# 1                                               it is so amazing
# 2                                                       thiccccc
# 3                                                        hate it
# 4  This game addicting and fun af. Only grinders play this shit.
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1602030454         1602030454      True         0            0
# 1         1602030354         1602030354      True         0            0
# 2         1602030239         1602030239      True         0            0
# ...

# %%
# ARK: Survival Evolved
adventure3 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Adventure)%20346110_ARKSurvivalEvolved.csv", low_memory=False)
adventure3.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77056947  english
# 1           1          33253572  english
# 2           2          61245030  english
# 3           3          77055624  english
# 4           4          77055438  english
#
#                                                                                                                                                                                                                                                                                               review  \
# 0                                                                                                                                                                   I, have played this game for a couple of years across both xbox and pc and i really like the way this game is its grindy but fun
# ...

# %% [markdown]
# #### Indie Games Datasets

# %%
# Stardew Valley
indie1 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Indie)%20413150_StardewValley.csv", low_memory=False)
indie1.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77060556  english
# 1           1          77060374  english
# 2           2          77058275  english
# 3           3          77056782  english
# 4           4          77056491  english
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     review  \
# ...

# %%
# Beat Saber
indie2 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Indie)%20620980_BeatSaber.csv", low_memory=False)
indie2.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77182806  english
# 1           1          77182703  english
# 2           2          77175496  english
# 3           3          77167007  english
# 4           4          77163777  english
#
#                                                                                                                                  review  \
# 0                                                                      Beat sabre is a very fun gmae, i enjoy it. best vr game, i guess
# 1  This is an amazing game, challenges and improves your reaction time, helps you lose weight, and a nice change to most other VR games
# 2                                                                          Must have when you buy VR, It's like a little exercise in VR
# 3                                                                                                      better than going to the gym ; )
# ...

# %%
# Phasmophobia
indie3 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Indie)%20739630_Phasmophobia.csv", low_memory=False)
indie3.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77060900  english
# 1           1          77060888  english
# 2           2          77060887  english
# 3           3          77060884  english
# 4           4          77060829  english
#
#                                                                                                                                                                                                                                                                                     review  \
# 0                                                                                                                                                                                                                   10 out of 10 would love to hear my friends scream at each other again.
# ...

# %% [markdown]
# #### Racing Games Datasets

# %%
# F1 2020
racing1 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Racing)%201080110_F12020.csv", low_memory=False)
racing1.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77059075  english
# 1           1          77058022  english
# 2           2          77057267  english
# 3           3          77056635  english
# 4           4          77054570  english
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 review  \
# ...

# %%
# Assetto Corsa
racing2 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Racing)%20244210_AssettoCorsa.csv", low_memory=False)
racing2.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77177205  english
# 1           1          77174661  english
# 2           2          11308633  english
# 3           3          77165484  english
# 4           4          77164316  english
#
# ...

# %%
# Assetto Corsa Competizione
racing3 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(Racing)%20805550_AssettoCorsaCompetizione.csv", low_memory=False)
racing3.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77186243  english
# 1           1          77183653  english
# 2           2          77182965  english
# 3           3          77115495  english
# 4           4          77112459  english
#
#                                                                                       review  \
# 0                                                           Simply the best simracing title.
# 1                                                                            Good Sim racing
# 2                                                                                 Me Likey\n
# 3                                                                         very good game !!!
# 4  Best GT3 sim you'll find, easy as that. Wish they hadn't removed regional pricing though.
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1602087740         1602087740      True         0            0
# ...

# %% [markdown]
# #### RPG Games Datasets

# %%
# The Elder Scrolls Online
rpg1 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(RPG)%20306130_TheElderScrollsOnline.csv", low_memory=False)
rpg1.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77058575  english
# 1           1          77057679  english
# 2           2          77057574  english
# 3           3          76578295  english
# 4           4          77053453  english
#
#                                                                                                                                                                                                                                                                                                         review  \
# 0                                                                                                                                                                                                                                                                                         Are the scrolls old?
# ...

# %%
# Final Fantasy XIV Online
rpg2 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(RPG)%2039210_FINALFANTASYXIVOnline.csv", low_memory=False)
rpg2.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          72837829  english
# 1           1          77154831  english
# 2           2          77154610  english
# 3           3          77147592  english
# 4           4          77146784  english
#
# ...

# %%
# Borderlands 3
rpg3 = pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1005/main/data/data_raw/(RPG)%20397540_Borderlands3.csv", low_memory=False)
rpg3.head()
# Out:
#    Unnamed: 0  recommendationid language  \
# 0           0          77059967  english
# 1           1          65066457  english
# 2           2          75247144  english
# 3           3          77057553  english
# 4           4          77051884  english
#
# ...
